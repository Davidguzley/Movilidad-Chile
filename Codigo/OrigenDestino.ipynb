# %%
from google.colab import drive

drive.mount("/content/gdrive")  
# !pwd
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/Shareddrives/Cortesanas de IA/Reto/Version 4.0

# %%
# %cd "/content/gdrive/Shareddrives/Cortesanas de IA/Reto/Version 4.0"
# !ls
# Out:
# /content/gdrive/Shareddrives/Cortesanas de IA/Reto/Version 4.0
# 'Matriz de viajes Enrique.ipynb'   trazas.csv	     viajes2.ipynb
#  matriz_viajes_v2.csv		   Untitled0.ipynb   xd.csv

# %%
import pandas as pd
import numpy as np

#df = pd.read_csv('matriz_viajes_v2.csv')
df = pd.read_csv('trazas.csv')

# %%
df
# Out:
#          Unnamed: 0                                           PHONE_ID  \
# 0                 0  00000000e3fc09803d408609f55cbf905120d3a41db564...
# 1                 1  00000000e3fc09803d408609f55cbf905120d3a41db564...
# 2                 2  00000000e3fc09803d408609f55cbf905120d3a41db564...
# 3                 3  00000000e3fc09803d408609f55cbf905120d3a41db564...
# 4                 4  00000000e3fc09803d408609f55cbf905120d3a41db564...
# ...             ...                                                ...
# 9350021     9350021  ffffa01d59b87f412bc0d8f47da668a910192bd61176ab...
# 9350022     9350022  ffffa17bcc4a44837795dbee241e641b0bf6e0f0f45408...
# 9350023     9350023  ffffa17bcc4a44837795dbee241e641b0bf6e0f0f45408...
# 9350024     9350024  ffffea064367ea293c32db026f6dee34efa6c464375ac9...
# 9350025     9350025  ffffea064367ea293c32db026f6dee34efa6c464375ac9...
#
#                 Coordenada               Hora_entrada  \
# 0        -33.3844,-70.5534  2021-01-01 00:09:15-03:00
# ...

# %%
df["Hora_entrada"] = pd.to_datetime(df["Hora_entrada"])
df["Hora_salida"] = pd.to_datetime(df["Hora_salida"])

# %%
mask = df['Hora_salida'] >= df['Hora_entrada']

# %%
mask.value_counts()
# Out:
# True    9350026
# Name: Distancia, dtype: int64

# %%
mask = df['Distancia'] >= 0

# %%
def tiemp(t1, t2):
    return (t1 - t2) / pd.Timedelta(hours = 1)

# %%
aux = {
    'PHONE_ID': [],
    'Comuna_Origen': [],
    'Comuna_Destino': [],
    'Hora_Salida': [],
    'Hora_Llegada': [],
    'Distancia': [],
    'Duracion': []
}

primer_registro = 1
dis_acum = 0

for i in range(len(df)):
  if i == len(df) - 1:
    if len(aux['PHONE_ID']) != len(aux['Duracion']):
        aux['Comuna_Destino'].append(df['Comuna'][i])
        aux['Distancia'].append(dis_acum)
        aux['Duracion'].append(tiempo_viaje)
        aux['Hora_Llegada'].append(df['Hora_entrada'][i])

  
  else:
    if df['PHONE_ID'][i] == df['PHONE_ID'][i + 1]:
      if primer_registro == 1:
        aux['PHONE_ID'].append(df['PHONE_ID'][i])
        aux['Comuna_Origen'].append(df['Comuna'][i])
        aux['Hora_Salida'].append(df['Hora_salida'][i])
        hora_temp_inicio = df['Hora_salida'][i]
        primer_registro = 0
        dis_acum = 0

      else:
        dis_acum = dis_acum + df['Distancia'][i]
        tiempo_viaje = tiemp(df['Hora_salida'][i], hora_temp_inicio)

        if df['Tiempo_en_comuna'][i] >= 1/3:
          if tiempo_viaje >= 2:
            if dis_acum >= 25:
              aux['Comuna_Destino'].append(df['Comuna'][i - 1])
              aux['Distancia'].append(dis_acum - df['Distancia'][i])
              aux['Duracion'].append(tiemp(df['Hora_entrada'][i - 1], hora_temp_inicio))
              aux['Hora_Llegada'].append(df['Hora_entrada'][i - 1])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]

            else:
              aux['Comuna_Destino'].append(df['Comuna'][i - 1])
              aux['Distancia'].append(dis_acum - df['Distancia'][i])
              aux['Duracion'].append(tiemp(df['Hora_entrada'][i - 1], hora_temp_inicio))
              aux['Hora_Llegada'].append(df['Hora_entrada'][i - 1])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]

          else:
            if dis_acum >= 25:
              aux['Comuna_Destino'].append(df['Comuna'][i - 1])
              aux['Distancia'].append(dis_acum - df['Distancia'][i])
              aux['Duracion'].append(tiemp(df['Hora_entrada'][i - 1], hora_temp_inicio))
              aux['Hora_Llegada'].append(df['Hora_entrada'][i - 1])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]

            else:
              aux['Comuna_Destino'].append(df['Comuna'][i])
              aux['Distancia'].append(dis_acum)
              aux['Duracion'].append(tiempo_viaje)
              aux['Hora_Llegada'].append(df['Hora_entrada'][i])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]
        
        else:
          if tiempo_viaje >= 2:
            if dis_acum >= 25:
              aux['Comuna_Destino'].append(df['Comuna'][i - 1])
              aux['Distancia'].append(dis_acum - df['Distancia'][i])
              aux['Duracion'].append(tiemp(df['Hora_entrada'][i - 1], hora_temp_inicio))
              aux['Hora_Llegada'].append(df['Hora_entrada'][i - 1])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]

            else:
              aux['Comuna_Destino'].append(df['Comuna'][i - 1])
              aux['Distancia'].append(dis_acum - df['Distancia'][i])
              aux['Duracion'].append(tiemp(df['Hora_entrada'][i - 1], hora_temp_inicio))
              aux['Hora_Llegada'].append(df['Hora_entrada'][i - 1])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]

          else:
            if dis_acum >= 25:
              aux['Comuna_Destino'].append(df['Comuna'][i - 1])
              aux['Distancia'].append(dis_acum - df['Distancia'][i])
              aux['Duracion'].append(tiemp(df['Hora_entrada'][i - 1], hora_temp_inicio))
              aux['Hora_Llegada'].append(df['Hora_entrada'][i - 1])
              dis_acum = 0

              aux['PHONE_ID'].append(df['PHONE_ID'][i])
              aux['Comuna_Origen'].append(df['Comuna'][i])
              aux['Hora_Salida'].append(df['Hora_salida'][i])
              hora_temp_inicio = df['Hora_salida'][i]

            else:
              continue

    else:
      if len(aux['PHONE_ID']) != len(aux['Duracion']):
        aux['Comuna_Destino'].append(df['Comuna'][i])
        aux['Distancia'].append(dis_acum)
        aux['Duracion'].append(tiempo_viaje)
        aux['Hora_Llegada'].append(df['Hora_entrada'][i])
      dis_acum = 0
      primer_registro = 1

# %%
len(aux['PHONE_ID'])
# Out:
# 3758312

# %%
len(aux['Duracion'])
# Out:
# 3758312

# %%
len(df2)
# Out:
# 9350026

# %%
osqui = pd.DataFrame.from_dict(aux)

# %%
osqui.describe()
# Out:
#           Distancia      Duracion
# count  3.758312e+06  3.758312e+06
# mean   3.902924e+00  7.085231e-01
# std    5.498937e+00  2.500140e+00
# min    0.000000e+00 -2.281778e+01
# 25%    0.000000e+00  3.344444e-01
# 50%    1.623878e+00  8.591667e-01
# 75%    4.932523e+00  1.468611e+00
# max    2.499992e+01  2.380500e+01

# %%
mask = osqui['Duracion'] < 2
osqui = osqui[mask]

# %%
mask = osqui['Duracion'] > 0
osqui = osqui[mask]

# %%
mask = osqui['Duracion'] < 0
mask.value_counts()
# Out:
# False    2938489
# Name: Duracion, dtype: int64

# %%
osqui.describe()
# Out:
#           Distancia      Duracion
# count  2.938489e+06  2.938489e+06
# mean   4.991819e+00  9.967051e-01
# std    5.765333e+00  5.313542e-01
# min    0.000000e+00  1.111111e-03
# 25%    1.138776e+00  5.036111e-01
# 50%    2.566055e+00  9.888889e-01
# 75%    6.550623e+00  1.458333e+00
# max    2.499992e+01  1.999722e+00

# %%
mask = osqui['Distancia'] > 0
osqui = osqui[mask]

# %%
osqui.describe()
# Out:
#           Distancia      Duracion
# count  2.780578e+06  2.780578e+06
# mean   5.275308e+00  9.921713e-01
# std    5.799245e+00  5.330863e-01
# min    9.282892e-03  1.111111e-03
# 25%    1.298208e+00  5.000000e-01
# 50%    2.783250e+00  9.811111e-01
# 75%    6.958994e+00  1.455833e+00
# max    2.499992e+01  1.999722e+00

# %%
osqui
# Out:
#                                                   PHONE_ID    Comuna_Origen  \
# 0        00000000e3fc09803d408609f55cbf905120d3a41db564...         Vitacura
# 1        00000000e3fc09803d408609f55cbf905120d3a41db564...       Las Condes
# 2        00000000e3fc09803d408609f55cbf905120d3a41db564...         Vitacura
# 3        00000000e3fc09803d408609f55cbf905120d3a41db564...       Las Condes
# 4        00000000e3fc09803d408609f55cbf905120d3a41db564...       Las Condes
# ...                                                    ...              ...
# 3758304  ffffa01d59b87f412bc0d8f47da668a910192bd61176ab...  Calera de Tango
# 3758305  ffffa01d59b87f412bc0d8f47da668a910192bd61176ab...  Calera de Tango
# 3758306  ffffa01d59b87f412bc0d8f47da668a910192bd61176ab...  Calera de Tango
# 3758307  ffffa01d59b87f412bc0d8f47da668a910192bd61176ab...  Calera de Tango
# 3758308  ffffa01d59b87f412bc0d8f47da668a910192bd61176ab...  Calera de Tango
#
# ...

# %%
osqui.to_csv('Matriz')
